# %%
import time
import datetime
import pandas as pd

# %%
ticker = 'AMZN'
period1 = int(time.mktime(datetime.datetime(2022, 12, 1, 23, 59).timetuple()))
period2 = int(time.mktime(datetime.datetime.now().timetuple()))
interval = '1d'

query_string = f'https://query1.finance.yahoo.com/v7/finance/download/{ticker}?period1={period1}&period2={period2}&interval={interval}&events=history&includeAdjustedClose=true'

df = pd.read_csv(query_string)

# %%
query_string
# Out:
# 'https://query1.finance.yahoo.com/v7/finance/download/AMZN?period1=1669939140&period2=1705051483&interval=1d&events=history&includeAdjustedClose=true'

# %%
datetime.datetime.now().timetuple()
# Out:
# time.struct_time(tm_year=2024, tm_mon=1, tm_mday=12, tm_hour=9, tm_min=26, tm_sec=38, tm_wday=4, tm_yday=12, tm_isdst=-1)

# %%
date = df

# %%
date
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-12-01   96.989998   97.230003   94.919998   95.500000   95.500000
# 1    2022-12-02   94.480003   95.360001   93.779999   94.129997   94.129997
# 2    2022-12-05   93.050003   94.059998   90.820000   91.010002   91.010002
# 3    2022-12-06   90.500000   91.040001   87.900002   88.250000   88.250000
# 4    2022-12-07   88.339996   89.889999   87.480003   88.459999   88.459999
# ..          ...         ...         ...         ...         ...         ...
# 274  2024-01-05  144.690002  146.589996  144.529999  145.240005  145.240005
# 275  2024-01-08  146.740005  149.399994  146.149994  149.100006  149.100006
# 276  2024-01-09  148.330002  151.710007  148.210007  151.369995  151.369995
# 277  2024-01-10  152.059998  154.419998  151.880005  153.729996  153.729996
# 278  2024-01-11  155.039993  157.169998  153.119995  155.179993  155.179993
#
#        Volume
# 0    68488000
# 1    72496400
# 2    71535500
# 3    75503600
# 4    68086900
# ..        ...
# 274  45124800
# 275  46757100
# 276  43812600
# 277  44421800
# 278  48958800
#
# [279 rows x 7 columns]

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-12-01   96.989998   97.230003   94.919998   95.500000   95.500000
# 1    2022-12-02   94.480003   95.360001   93.779999   94.129997   94.129997
# 2    2022-12-05   93.050003   94.059998   90.820000   91.010002   91.010002
# 3    2022-12-06   90.500000   91.040001   87.900002   88.250000   88.250000
# 4    2022-12-07   88.339996   89.889999   87.480003   88.459999   88.459999
# ..          ...         ...         ...         ...         ...         ...
# 274  2024-01-05  144.690002  146.589996  144.529999  145.240005  145.240005
# 275  2024-01-08  146.740005  149.399994  146.149994  149.100006  149.100006
# 276  2024-01-09  148.330002  151.710007  148.210007  151.369995  151.369995
# 277  2024-01-10  152.059998  154.419998  151.880005  153.729996  153.729996
# 278  2024-01-11  155.039993  157.169998  153.119995  155.179993  155.179993
#
#        Volume
# 0    68488000
# 1    72496400
# 2    71535500
# 3    75503600
# 4    68086900
# ..        ...
# 274  45124800
# 275  46757100
# 276  43812600
# 277  44421800
# 278  48958800
#
# [279 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Close'])

# %%
df = df[['Date', 'Close']]

# %%
df
# Out:
#            Date       Close
# 0    2022-12-01   95.500000
# 1    2022-12-02   94.129997
# 2    2022-12-05   91.010002
# 3    2022-12-06   88.250000
# 4    2022-12-07   88.459999
# ..          ...         ...
# 274  2024-01-05  145.240005
# 275  2024-01-08  149.100006
# 276  2024-01-09  151.369995
# 277  2024-01-10  153.729996
# 278  2024-01-11  155.179993
#
# [279 rows x 2 columns]

# %%
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-13-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0     2022-12-01
# 1     2022-12-02
# 2     2022-12-05
# 3     2022-12-06
# 4     2022-12-07
#          ...
# 274   2024-01-05
# 275   2024-01-08
# 276   2024-01-09
# 277   2024-01-10
# 278   2024-01-11
# Name: Date, Length: 279, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 2022-12-01   95.500000
# 2022-12-02   94.129997
# 2022-12-05   91.010002
# 2022-12-06   88.250000
# 2022-12-07   88.459999
# ...                ...
# 2024-01-05  145.240005
# 2024-01-08  149.100006
# 2024-01-09  151.369995
# 2024-01-10  153.729996
# 2024-01-11  155.179993
#
# [279 rows x 1 columns]

# %%
dt = date['Date'].iloc[3]

# %%
dt
# Out:
# '2022-12-06'

# %%
curr = str(datetime.datetime.now()-datetime.timedelta(days=4))

# %%
curr
# Out:
# '2024-01-08 09:33:18.994171'

# %%
curr = curr[0:10]

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

windowed_df = df_to_windowed_df(df,
                                dt,
                                curr,
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2022-12-06   95.500000   94.129997   91.010002   88.250000
# 1    2022-12-07   94.129997   91.010002   88.250000   88.459999
# 2    2022-12-08   91.010002   88.250000   88.459999   90.349998
# 3    2022-12-09   88.250000   88.459999   90.349998   89.089996
# 4    2022-12-12   88.459999   90.349998   89.089996   90.550003
# ..          ...         ...         ...         ...         ...
# 268  2024-01-02  153.339996  153.380005  151.940002  149.929993
# 269  2024-01-03  153.380005  151.940002  149.929993  148.470001
# 270  2024-01-04  151.940002  149.929993  148.470001  144.570007
# 271  2024-01-05  149.929993  148.470001  144.570007  145.240005
# 272  2024-01-08  148.470001  144.570007  145.240005  149.100006
#
# [273 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1]))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((273,), (273, 3), (273,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([keras.layers.Input((3, 1)),
                    tf.keras.layers.Bidirectional(keras.layers.LSTM(64)),
                    keras.layers.Dense(32, activation='relu'),
                    keras.layers.Dense(32, activation='relu'),
                    keras.layers.Dense(1)])

model.compile(loss='mse',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 7s 238ms/step - loss: 13070.7656 - mean_absolute_error: 112.9163 - val_loss: 18753.9590 - val_mean_absolute_error: 136.6930
# Epoch 2/100
# 7/7 [==============================] - 0s 10ms/step - loss: 12932.8232 - mean_absolute_error: 112.3004 - val_loss: 18562.8965 - val_mean_absolute_error: 135.9920
# Epoch 3/100
# 7/7 [==============================] - 0s 11ms/step - loss: 12744.9238 - mean_absolute_error: 111.4571 - val_loss: 18287.3887 - val_mean_absolute_error: 134.9749
# Epoch 4/100
# 7/7 [==============================] - 0s 11ms/step - loss: 12476.0898 - mean_absolute_error: 110.2435 - val_loss: 17884.8574 - val_mean_absolute_error: 133.4756
# Epoch 5/100
# 7/7 [==============================] - 0s 11ms/step - loss: 12104.0898 - mean_absolute_error: 108.5603 - val_loss: 17361.9141 - val_mean_absolute_error: 131.5028
# Epoch 6/100
# 7/7 [==============================] - 0s 11ms/step - loss: 11646.9219 - mean_absolute_error: 106.4208 - val_loss: 16740.6895 - val_mean_absolute_error: 129.1183
# Epoch 7/100
# 7/7 [==============================] - 0s 12ms/step - loss: 11060.8145 - mean_absolute_error: 103.6122 - val_loss: 15921.5693 - val_mean_absolute_error: 125.9028
# Epoch 8/100
# 7/7 [==============================] - 0s 11ms/step - loss: 10226.6318 - mean_absolute_error: 99.4302 - val_loss: 14665.3164 - val_mean_absolute_error: 120.8051
# Epoch 9/100
# 7/7 [==============================] - 0s 14ms/step - loss: 8999.2021 - mean_absolute_error: 92.9295 - val_loss: 12844.8428 - val_mean_absolute_error: 113.0156
# Epoch 10/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7376.5254 - mean_absolute_error: 83.7790 - val_loss: 10596.7803 - val_mean_absolute_error: 102.5790
# Epoch 11/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5487.4233 - mean_absolute_error: 71.4576 - val_loss: 7876.5928 - val_mean_absolute_error: 88.3209
# Epoch 12/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3523.0151 - mean_absolute_error: 55.9630 - val_loss: 5158.0938 - val_mean_absolute_error: 71.3038
# Epoch 13/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1876.4003 - mean_absolute_error: 38.6082 - val_loss: 2900.3770 - val_mean_absolute_error: 53.1608
# Epoch 14/100
# 7/7 [==============================] - 0s 11ms/step - loss: 776.2308 - mean_absolute_error: 22.5585 - val_loss: 1260.2483 - val_mean_absolute_error: 34.4293
# Epoch 15/100
# 7/7 [==============================] - 0s 12ms/step - loss: 391.0809 - mean_absolute_error: 17.8908 - val_loss: 458.7001 - val_mean_absolute_error: 19.6574
# Epoch 16/100
# 7/7 [==============================] - 0s 11ms/step - loss: 383.2599 - mean_absolute_error: 17.2006 - val_loss: 317.3880 - val_mean_absolute_error: 15.9608
# Epoch 17/100
# 7/7 [==============================] - 0s 11ms/step - loss: 380.3033 - mean_absolute_error: 16.9988 - val_loss: 400.4199 - val_mean_absolute_error: 18.2023
# Epoch 18/100
# 7/7 [==============================] - 0s 11ms/step - loss: 337.8153 - mean_absolute_error: 16.6557 - val_loss: 562.6031 - val_mean_absolute_error: 22.2228
# Epoch 19/100
# 7/7 [==============================] - 0s 11ms/step - loss: 314.0694 - mean_absolute_error: 16.3846 - val_loss: 698.8711 - val_mean_absolute_error: 25.1300
# Epoch 20/100
# 7/7 [==============================] - 0s 11ms/step - loss: 303.7771 - mean_absolute_error: 15.9006 - val_loss: 729.8859 - val_mean_absolute_error: 25.7889
# Epoch 21/100
# 7/7 [==============================] - 0s 11ms/step - loss: 296.6186 - mean_absolute_error: 15.7502 - val_loss: 665.0833 - val_mean_absolute_error: 24.4786
# Epoch 22/100
# 7/7 [==============================] - 0s 14ms/step - loss: 280.4496 - mean_absolute_error: 15.2865 - val_loss: 648.5452 - val_mean_absolute_error: 24.2529
# Epoch 23/100
# 7/7 [==============================] - 0s 14ms/step - loss: 258.4933 - mean_absolute_error: 14.7300 - val_loss: 548.7259 - val_mean_absolute_error: 22.0949
# Epoch 24/100
# 7/7 [==============================] - 0s 14ms/step - loss: 240.2850 - mean_absolute_error: 14.1890 - val_loss: 502.7297 - val_mean_absolute_error: 21.1057
# Epoch 25/100
# 7/7 [==============================] - 0s 12ms/step - loss: 222.8327 - mean_absolute_error: 13.6806 - val_loss: 468.4486 - val_mean_absolute_error: 20.3648
# Epoch 26/100
# 7/7 [==============================] - 0s 14ms/step - loss: 197.6457 - mean_absolute_error: 12.8495 - val_loss: 413.6346 - val_mean_absolute_error: 18.9668
# Epoch 27/100
# 7/7 [==============================] - 0s 14ms/step - loss: 174.0941 - mean_absolute_error: 12.0004 - val_loss: 377.8959 - val_mean_absolute_error: 18.0867
# Epoch 28/100
# 7/7 [==============================] - 0s 11ms/step - loss: 140.3420 - mean_absolute_error: 10.7000 - val_loss: 351.1738 - val_mean_absolute_error: 17.4563
# Epoch 29/100
# 7/7 [==============================] - 0s 11ms/step - loss: 105.3810 - mean_absolute_error: 9.0221 - val_loss: 274.4171 - val_mean_absolute_error: 15.1464
# Epoch 30/100
# 7/7 [==============================] - 0s 14ms/step - loss: 72.1650 - mean_absolute_error: 7.3747 - val_loss: 208.2176 - val_mean_absolute_error: 13.1242
# Epoch 31/100
# 7/7 [==============================] - 0s 11ms/step - loss: 43.9596 - mean_absolute_error: 5.4860 - val_loss: 143.4588 - val_mean_absolute_error: 10.8109
# Epoch 32/100
# 7/7 [==============================] - 0s 14ms/step - loss: 23.9863 - mean_absolute_error: 3.7915 - val_loss: 80.4942 - val_mean_absolute_error: 8.1078
# Epoch 33/100
# 7/7 [==============================] - 0s 14ms/step - loss: 14.0196 - mean_absolute_error: 2.9054 - val_loss: 56.9702 - val_mean_absolute_error: 6.9105
# Epoch 34/100
# 7/7 [==============================] - 0s 13ms/step - loss: 10.0820 - mean_absolute_error: 2.4805 - val_loss: 42.7972 - val_mean_absolute_error: 6.0485
# Epoch 35/100
# 7/7 [==============================] - 0s 14ms/step - loss: 8.8645 - mean_absolute_error: 2.3154 - val_loss: 33.7079 - val_mean_absolute_error: 5.3250
# Epoch 36/100
# 7/7 [==============================] - 0s 11ms/step - loss: 9.6159 - mean_absolute_error: 2.4241 - val_loss: 33.0669 - val_mean_absolute_error: 5.3152
# Epoch 37/100
# 7/7 [==============================] - 0s 15ms/step - loss: 8.0167 - mean_absolute_error: 2.1698 - val_loss: 30.0858 - val_mean_absolute_error: 5.0625
# Epoch 38/100
# 7/7 [==============================] - 0s 12ms/step - loss: 8.6971 - mean_absolute_error: 2.3265 - val_loss: 31.4564 - val_mean_absolute_error: 5.1862
# Epoch 39/100
# 7/7 [==============================] - 0s 12ms/step - loss: 8.3779 - mean_absolute_error: 2.3097 - val_loss: 36.9647 - val_mean_absolute_error: 5.6247
# Epoch 40/100
# 7/7 [==============================] - 0s 12ms/step - loss: 8.2818 - mean_absolute_error: 2.2912 - val_loss: 27.8414 - val_mean_absolute_error: 4.8535
# Epoch 41/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.3528 - mean_absolute_error: 2.0582 - val_loss: 25.5839 - val_mean_absolute_error: 4.6361
# Epoch 42/100
# 7/7 [==============================] - 0s 11ms/step - loss: 8.2467 - mean_absolute_error: 2.2126 - val_loss: 26.1188 - val_mean_absolute_error: 4.6876
# Epoch 43/100
# 7/7 [==============================] - 0s 14ms/step - loss: 8.0621 - mean_absolute_error: 2.1073 - val_loss: 28.4412 - val_mean_absolute_error: 4.9193
# Epoch 44/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.8763 - mean_absolute_error: 2.2195 - val_loss: 34.1447 - val_mean_absolute_error: 5.4076
# Epoch 45/100
# 7/7 [==============================] - 0s 13ms/step - loss: 8.3770 - mean_absolute_error: 2.2279 - val_loss: 26.6114 - val_mean_absolute_error: 4.7516
# Epoch 46/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.2475 - mean_absolute_error: 2.0580 - val_loss: 23.2113 - val_mean_absolute_error: 4.3930
# Epoch 47/100
# 7/7 [==============================] - 0s 13ms/step - loss: 7.4705 - mean_absolute_error: 2.1550 - val_loss: 26.0596 - val_mean_absolute_error: 4.7008
# Epoch 48/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.9812 - mean_absolute_error: 2.0416 - val_loss: 28.8277 - val_mean_absolute_error: 4.9580
# Epoch 49/100
# 7/7 [==============================] - 0s 13ms/step - loss: 7.2890 - mean_absolute_error: 2.0471 - val_loss: 21.5905 - val_mean_absolute_error: 4.2164
# Epoch 50/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.1016 - mean_absolute_error: 2.0504 - val_loss: 22.7889 - val_mean_absolute_error: 4.3634
# Epoch 51/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.0423 - mean_absolute_error: 2.0329 - val_loss: 22.4651 - val_mean_absolute_error: 4.3322
# Epoch 52/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.9200 - mean_absolute_error: 2.0304 - val_loss: 26.9895 - val_mean_absolute_error: 4.7944
# Epoch 53/100
# 7/7 [==============================] - 0s 12ms/step - loss: 7.3705 - mean_absolute_error: 2.0482 - val_loss: 23.5063 - val_mean_absolute_error: 4.4493
# Epoch 54/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.1133 - mean_absolute_error: 2.0107 - val_loss: 19.4977 - val_mean_absolute_error: 3.9708
# Epoch 55/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.1062 - mean_absolute_error: 2.0184 - val_loss: 21.1979 - val_mean_absolute_error: 4.1956
# Epoch 56/100
# 7/7 [==============================] - 0s 13ms/step - loss: 6.7676 - mean_absolute_error: 1.9768 - val_loss: 22.5930 - val_mean_absolute_error: 4.3537
# Epoch 57/100
# 7/7 [==============================] - 0s 17ms/step - loss: 6.7101 - mean_absolute_error: 1.9641 - val_loss: 22.7081 - val_mean_absolute_error: 4.3607
# Epoch 58/100
# 7/7 [==============================] - 0s 12ms/step - loss: 6.7877 - mean_absolute_error: 1.9924 - val_loss: 19.0069 - val_mean_absolute_error: 3.9164
# Epoch 59/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.7032 - mean_absolute_error: 1.9771 - val_loss: 19.9558 - val_mean_absolute_error: 4.0545
# Epoch 60/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.5781 - mean_absolute_error: 1.9552 - val_loss: 20.0918 - val_mean_absolute_error: 4.0734
# Epoch 61/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.6057 - mean_absolute_error: 1.9349 - val_loss: 24.1712 - val_mean_absolute_error: 4.5237
# Epoch 62/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.9780 - mean_absolute_error: 2.0185 - val_loss: 20.9793 - val_mean_absolute_error: 4.1757
# Epoch 63/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.7577 - mean_absolute_error: 1.9686 - val_loss: 20.6903 - val_mean_absolute_error: 4.1418
# Epoch 64/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.5839 - mean_absolute_error: 1.9571 - val_loss: 18.3100 - val_mean_absolute_error: 3.8459
# Epoch 65/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.2721 - mean_absolute_error: 2.0760 - val_loss: 17.7785 - val_mean_absolute_error: 3.7707
# Epoch 66/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.1896 - mean_absolute_error: 2.0644 - val_loss: 21.8464 - val_mean_absolute_error: 4.2779
# Epoch 67/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.4141 - mean_absolute_error: 1.9501 - val_loss: 17.5977 - val_mean_absolute_error: 3.7546
# Epoch 68/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.4871 - mean_absolute_error: 1.9445 - val_loss: 18.9184 - val_mean_absolute_error: 3.9346
# Epoch 69/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.6850 - mean_absolute_error: 1.9633 - val_loss: 24.5226 - val_mean_absolute_error: 4.5595
# Epoch 70/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.0256 - mean_absolute_error: 2.0139 - val_loss: 17.6344 - val_mean_absolute_error: 3.7679
# Epoch 71/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.8833 - mean_absolute_error: 1.9942 - val_loss: 17.4075 - val_mean_absolute_error: 3.7376
# Epoch 72/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.8586 - mean_absolute_error: 2.0277 - val_loss: 18.0812 - val_mean_absolute_error: 3.8327
# Epoch 73/100
# 7/7 [==============================] - 0s 12ms/step - loss: 6.8837 - mean_absolute_error: 2.0046 - val_loss: 17.0103 - val_mean_absolute_error: 3.6828
# Epoch 74/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.6137 - mean_absolute_error: 1.9592 - val_loss: 18.7246 - val_mean_absolute_error: 3.9112
# Epoch 75/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.5641 - mean_absolute_error: 1.9425 - val_loss: 15.5680 - val_mean_absolute_error: 3.4412
# Epoch 76/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.1863 - mean_absolute_error: 2.0443 - val_loss: 21.4761 - val_mean_absolute_error: 4.2416
# Epoch 77/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.5153 - mean_absolute_error: 1.9124 - val_loss: 18.4926 - val_mean_absolute_error: 3.8788
# Epoch 78/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.7150 - mean_absolute_error: 1.9982 - val_loss: 17.1127 - val_mean_absolute_error: 3.7009
# Epoch 79/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.8424 - mean_absolute_error: 1.9424 - val_loss: 15.2914 - val_mean_absolute_error: 3.3892
# Epoch 80/100
# 7/7 [==============================] - 0s 13ms/step - loss: 7.6396 - mean_absolute_error: 2.1625 - val_loss: 20.3882 - val_mean_absolute_error: 4.1134
# Epoch 81/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.5690 - mean_absolute_error: 1.9409 - val_loss: 18.6701 - val_mean_absolute_error: 3.9035
# Epoch 82/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.2881 - mean_absolute_error: 1.9029 - val_loss: 18.6906 - val_mean_absolute_error: 3.9051
# Epoch 83/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.2649 - mean_absolute_error: 1.8944 - val_loss: 16.0921 - val_mean_absolute_error: 3.5494
# Epoch 84/100
# 7/7 [==============================] - 0s 12ms/step - loss: 6.4330 - mean_absolute_error: 1.9474 - val_loss: 19.1034 - val_mean_absolute_error: 3.9627
# Epoch 85/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.3702 - mean_absolute_error: 1.9247 - val_loss: 17.4724 - val_mean_absolute_error: 3.7528
# Epoch 86/100
# 7/7 [==============================] - 0s 15ms/step - loss: 6.3781 - mean_absolute_error: 1.9196 - val_loss: 17.3801 - val_mean_absolute_error: 3.7354
# Epoch 87/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.1979 - mean_absolute_error: 1.9023 - val_loss: 15.4736 - val_mean_absolute_error: 3.4606
# Epoch 88/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.4855 - mean_absolute_error: 1.9337 - val_loss: 16.1313 - val_mean_absolute_error: 3.5690
# Epoch 89/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.2311 - mean_absolute_error: 1.9139 - val_loss: 16.8771 - val_mean_absolute_error: 3.6753
# Epoch 90/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.2343 - mean_absolute_error: 1.8900 - val_loss: 15.7955 - val_mean_absolute_error: 3.5215
# Epoch 91/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.1536 - mean_absolute_error: 2.0803 - val_loss: 19.2267 - val_mean_absolute_error: 3.9807
# Epoch 92/100
# 7/7 [==============================] - 0s 13ms/step - loss: 8.2542 - mean_absolute_error: 2.2123 - val_loss: 27.8228 - val_mean_absolute_error: 4.8931
# Epoch 93/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.4268 - mean_absolute_error: 2.1594 - val_loss: 16.1647 - val_mean_absolute_error: 3.5752
# Epoch 94/100
# 7/7 [==============================] - 0s 14ms/step - loss: 6.5474 - mean_absolute_error: 1.9525 - val_loss: 15.8380 - val_mean_absolute_error: 3.5254
# Epoch 95/100
# 7/7 [==============================] - 0s 11ms/step - loss: 6.5083 - mean_absolute_error: 1.9443 - val_loss: 14.6461 - val_mean_absolute_error: 3.3199
# Epoch 96/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.3276 - mean_absolute_error: 2.0397 - val_loss: 14.7309 - val_mean_absolute_error: 3.3350
# Epoch 97/100
# 7/7 [==============================] - 0s 12ms/step - loss: 7.4189 - mean_absolute_error: 2.0960 - val_loss: 20.4883 - val_mean_absolute_error: 4.1279
# Epoch 98/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.4472 - mean_absolute_error: 2.1073 - val_loss: 21.7559 - val_mean_absolute_error: 4.2589
# Epoch 99/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.2660 - mean_absolute_error: 2.0378 - val_loss: 17.8665 - val_mean_absolute_error: 3.8079
# Epoch 100/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.2184 - mean_absolute_error: 1.9021 - val_loss: 16.8152 - val_mean_absolute_error: 3.6600

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 5ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
dates_test
# Out:
# array([Timestamp('2023-11-28 00:00:00'), Timestamp('2023-11-29 00:00:00'),
#        Timestamp('2023-11-30 00:00:00'), Timestamp('2023-12-01 00:00:00'),
#        Timestamp('2023-12-04 00:00:00'), Timestamp('2023-12-05 00:00:00'),
#        Timestamp('2023-12-06 00:00:00'), Timestamp('2023-12-07 00:00:00'),
#        Timestamp('2023-12-08 00:00:00'), Timestamp('2023-12-11 00:00:00'),
#        Timestamp('2023-12-12 00:00:00'), Timestamp('2023-12-13 00:00:00'),
#        Timestamp('2023-12-14 00:00:00'), Timestamp('2023-12-15 00:00:00'),
#        Timestamp('2023-12-18 00:00:00'), Timestamp('2023-12-19 00:00:00'),
#        Timestamp('2023-12-20 00:00:00'), Timestamp('2023-12-21 00:00:00'),
#        Timestamp('2023-12-22 00:00:00'), Timestamp('2023-12-26 00:00:00'),
#        Timestamp('2023-12-27 00:00:00'), Timestamp('2023-12-28 00:00:00'),
#        Timestamp('2023-12-29 00:00:00'), Timestamp('2024-01-02 00:00:00'),
#        Timestamp('2024-01-03 00:00:00'), Timestamp('2024-01-04 00:00:00'),
#        Timestamp('2024-01-05 00:00:00'), Timestamp('2024-01-08 00:00:00')],
#       dtype=object)

# %%
test_predictions
# Out:
# array([142.23544, 142.02396, 141.8244 , 141.6912 , 141.97083, 141.18729,
#        141.93887, 140.98283, 141.92418, 142.00072, 141.6306 , 142.18031,
#        142.54291, 142.21326, 143.03467, 143.9872 , 144.10732, 143.90227,
#        144.2617 , 144.12234, 144.18465, 144.15308, 144.16074, 143.8268 ,
#        143.29051, 142.7798 , 141.31577, 141.42625], dtype=float32)

# %%
df
# Out:
#                  Close
# Date
# 2022-12-01   95.500000
# 2022-12-02   94.129997
# 2022-12-05   91.010002
# 2022-12-06   88.250000
# 2022-12-07   88.459999
# ...                ...
# 2024-01-05  145.240005
# 2024-01-08  149.100006
# 2024-01-09  151.369995
# 2024-01-10  153.729996
# 2024-01-11  155.179993
#
# [279 rows x 1 columns]

# %%
req = windowed_df.tail(3)
req['Target']
# Out:
# 270    144.570007
# 271    145.240005
# 272    149.100006
# Name: Target, dtype: float64

# %%
inp = tuple(req['Target'])

# %%
inp
# Out:
# (144.570007, 145.240005, 149.100006)

# %%
npin = np.asarray(inp)
rs = npin.reshape(1, -1)
stk_pred = model.predict(rs)
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
stk_pred
# Out:
# array([[142.49829]], dtype=float32)

# %%
today = float(stk_pred)

# %%
today
# Out:
# 142.498291015625

# %%
req1 = windowed_df.tail(2)
tom = list(req1['Target'])

# %%
tom = tom + [today,]

# %%
tom
# Out:
# [145.240005, 149.100006, 142.498291015625]

# %%
tom1 = tuple(tom)

# %%
tom1
# Out:
# (145.240005, 149.100006, 142.498291015625)

# %%
npin = np.asarray(tom1)
rs = npin.reshape(1, -1)
tom_pred = model.predict(rs)
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
tom_pred
# Out:
# array([[140.20671]], dtype=float32)
